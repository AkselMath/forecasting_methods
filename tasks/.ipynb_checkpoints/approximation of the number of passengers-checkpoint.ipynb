# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize

import math

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
ausair = pd.read_csv('data/passengers.csv')
ausair = ausair['num_passengers']

# %%
plt.figure(figsize=(12, 4), dpi=150)
plt.plot(ausair)
plt.show()

# %%
a = lambda y: pow(2, y)
np.array( list( map(a, range(3)) ) )
# Out:
# array([1, 2, 4])

# %%
t = 1
a = lambda y: math.cos(2*y*math.pi*t)
np.array( list( map(a, range(3)) ) )
# Out:
# array([1., 1., 1.])

# %%
def approximation(data: np.array, theta: np.array, beta1: np.array, beta2: np.array,  N: int, s:int) -> np.array:
    forcast = []
    for i in range(len(data)):
        a = lambda y: pow(i, y)
        fur_cos = lambda n: math.cos((2 * y * math.pi * t) / s)
        fur_sin = lambda n: math.sin((2 * y * math.pi * t) / s)
        
        pred = np.array( list( map(a, range(3)) ) ) @ theta + np.array( list( map(fur_cos, range(N)) ) ) @ beta1 + np.array( list( map(fur_sin, range(N)) ) ) @ beta2
        forcast.append(pred)
    return np.array(forcast)
